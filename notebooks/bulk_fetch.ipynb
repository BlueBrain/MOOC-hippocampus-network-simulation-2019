# %%
SIMULATION_IDS=PLACEHOLDER

# %%
# !pip install -q https://github.com/BlueBrain/MOOC-hippocampus-network-simulation-2019/raw/create_package/dynamic_analysis_pkg/dist/dynamic_analysis_pkg-0.1.5.tar.gz

# %%
import dynamic_analysis_pkg

# %%
# Fetch all the simulation results
result = dynamic_analysis_pkg.FetchMultipleResults(oauth.get_token(), SIMULATION_IDS)
# Out:
# (1/4)
# Creating working directory: /home/jovyan/tmp/test_pull_unicore/8b42381b-7004-4ad0-b426-3693187e907d
# Fetching results of: Central Column - Docker parallel - 3 Nodes - 300ms - NO report
# - BlueConfig downloaded
# No reports were found
# - out.dat downloaded
# (2/4)
# Creating working directory: /home/jovyan/tmp/test_pull_unicore/77022196-e7f3-4245-881b-aecb22a7ba08
# Fetching results of: Random250 - 300 ms - 1 Nodes - no reports
# - BlueConfig downloaded
# No reports were found
# - out.dat downloaded
# (3/4)
# Creating working directory: /home/jovyan/tmp/test_pull_unicore/ca36fa35-34d8-4091-9ad0-345c345d129a
# Fetching results of: Random250 - 300 ms - 1 Nodes
# - BlueConfig downloaded
# - Random250Central_report_0.bbp downloaded
# - out.dat downloaded
# (4/4)
# Creating working directory: /home/jovyan/tmp/test_pull_unicore/05b41bbd-f803-47e5-9bbc-d41797d33fb6
# Fetching results of: Central Column (2.5K) - 300 ms - 3 Nodes
# - BlueConfig downloaded
# ...

# %%
# Get the BlueConfigs for all the Simulations
for sim_result in result.values:
    print(sim_result.blueconfig)
# Out:
# /home/jovyan/tmp/test_pull_unicore/8b42381b-7004-4ad0-b426-3693187e907d/BlueConfig
# /home/jovyan/tmp/test_pull_unicore/77022196-e7f3-4245-881b-aecb22a7ba08/BlueConfig
# /home/jovyan/tmp/test_pull_unicore/ca36fa35-34d8-4091-9ad0-345c345d129a/BlueConfig
# /home/jovyan/tmp/test_pull_unicore/05b41bbd-f803-47e5-9bbc-d41797d33fb6/BlueConfig

# %%
# Get the path to the circuit
result.values[0].circuit_dir
# Out:
# '/mnt/circuits/O1/20181114'
