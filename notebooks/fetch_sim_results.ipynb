# %%
# !pip install -q https://github.com/BlueBrain/MOOC-hippocampus-network-simulation-2019/raw/create_package/dynamic_analysis_pkg/dist/dynamic_analysis_pkg-0.1.3.tar.gz

# %%
import dynamic_analysis_pkg

# %%
results = Results(oauth.get_token(), 'SIMULATION_ID')
# Out:
# Fetching results of: Central column - 3 nodes - 150 ms
# - BlueConfig downloaded
# - mc2_Column_report_0.bbp downloaded
# - out.dat downloaded

# %%
results.blueconfig
# Out:
# '/home/jovyan/tmp/test_pull_unicore/BlueConfig'

# %%
results.circuit_dir
# Out:
# '/mnt/circuits/O1/20181114'
